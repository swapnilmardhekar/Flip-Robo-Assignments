# %%
from bs4 import BeautifulSoup
import requests

# %%
import pandas as pd

# %%
web= requests.get('https://en.wikipedia.org/wiki/Main_Page')

# %%
web
# Out:
# <Response [200]>

# %%
bs=BeautifulSoup(web.content)

# %%
h1=[]

# %%
for i in bs.find_all('h1', class_='firstHeading mw-first-heading'):
    h1.append(i.text.split('|')[0])

# %%
h1
# Out:
# ['Main Page']

# %%
h2=[]

# %%
for i in bs.find_all('h2', class_='mp-h2'):
    h2.append(i.text.split('|')[0])

# %%
h2
# Out:
# ["From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %%
len(h2)
# Out:
# 8

# %%
h3=[]
for i in bs.find_all('h3', class_='vector-menu-heading'):
    h3.append(i.text.split('|')[0])

# %%
h3
# Out:
# ['\nPersonal tools\n',
#  '\nNamespaces\n',
#  '\nViews\n',
#  '\nNavigation\n',
#  '\nContribute\n',
#  '\nTools\n',
#  '\nPrint/export\n',
#  '\nIn other projects\n',
#  '\nLanguages\n']

# %%
h3 = [i.replace('\n','') for i in h3]

# %%
h3
# Out:
# ['Personal tools',
#  'Namespaces',
#  'Views',
#  'Navigation',
#  'Contribute',
#  'Tools',
#  'Print/export',
#  'In other projects',
#  'Languages']

# %%
len(h3)
# Out:
# 9

# %%
headers = []
headers.extend(h1)
headers.extend(h2)
headers.extend(h3)
#headers.append(h1)
#headers.append(h2)
#headers.append(h3)

# %%
headers
# Out:
# ['Main Page',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages',
#  'Personal tools',
#  'Namespaces',
#  'Views',
#  'Navigation',
#  'Contribute',
#  'Tools',
#  'Print/export',
#  'In other projects',
#  'Languages']

# %%
df= pd.DataFrame({'headers':headers})

# %%
df
# Out:
#                           headers
# 0                       Main Page
# 1   From today's featured article
# 2                Did you know ...
# 3                     In the news
# 4                     On this day
# 5        Today's featured picture
# 6        Other areas of Wikipedia
# 7     Wikipedia's sister projects
# 8             Wikipedia languages
# 9                  Personal tools
# 10                     Namespaces
# 11                          Views
# 12                     Navigation
# 13                     Contribute
# 14                          Tools
# 15                   Print/export
# 16              In other projects
# 17                      Languages

# %% [markdown]
# ## IMDB Films

# %%
web2 = requests.get('https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc')

# %%
web2
# Out:
# <Response [200]>

# %%
bs= BeautifulSoup(web2.content)

# %%
titles= []
for i in bs.find_all('h3',class_='lister-item-header'):
    titles.append(i.text.split('|')[0])

# %%
titles
# Out:
# ['\n1.\nThe Shawshank Redemption\n(1994)\n',
#  '\n2.\nThe Godfather\n(1972)\n',
#  '\n3.\nThe Dark Knight\n(2008)\n',
#  '\n4.\nThe Lord of the Rings: The Return of the King\n(2003)\n',
#  "\n5.\nSchindler's List\n(1993)\n",
#  '\n6.\nThe Godfather Part II\n(1974)\n',
#  '\n7.\n12 Angry Men\n(1957)\n',
#  '\n8.\nPulp Fiction\n(1994)\n',
#  '\n9.\nInception\n(2010)\n',
#  '\n10.\nThe Lord of the Rings: The Two Towers\n(2002)\n',
#  '\n11.\nFight Club\n(1999)\n',
#  '\n12.\nThe Lord of the Rings: The Fellowship of the Ring\n(2001)\n',
#  '\n13.\nForrest Gump\n(1994)\n',
#  '\n14.\nIl buono, il brutto, il cattivo\n(1966)\n',
#  '\n15.\nThe Matrix\n(1999)\n',
#  '\n16.\nGoodfellas\n(1990)\n',
#  '\n17.\nThe Empire Strikes Back\n(1980)\n',
#  "\n18.\nOne Flew Over the Cuckoo's Nest\n(1975)\n",
#  '\n19.\nInterstellar\n(2014)\n',
#  '\n20.\nCidade de Deus\n(2002)\n',
#  '\n21.\nSen to Chihiro no kamikakushi\n(2001)\n',
#  '\n22.\nSaving Private Ryan\n(1998)\n',
# ...

# %%
titles = [x.replace('\n', '')for x in titles]

# %%
titles
# Out:
# ['1.The Shawshank Redemption(1994)',
#  '2.The Godfather(1972)',
#  '3.The Dark Knight(2008)',
#  '4.The Lord of the Rings: The Return of the King(2003)',
#  "5.Schindler's List(1993)",
#  '6.The Godfather Part II(1974)',
#  '7.12 Angry Men(1957)',
#  '8.Pulp Fiction(1994)',
#  '9.Inception(2010)',
#  '10.The Lord of the Rings: The Two Towers(2002)',
#  '11.Fight Club(1999)',
#  '12.The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '13.Forrest Gump(1994)',
#  '14.Il buono, il brutto, il cattivo(1966)',
#  '15.The Matrix(1999)',
#  '16.Goodfellas(1990)',
#  '17.The Empire Strikes Back(1980)',
#  "18.One Flew Over the Cuckoo's Nest(1975)",
#  '19.Interstellar(2014)',
#  '20.Cidade de Deus(2002)',
#  '21.Sen to Chihiro no kamikakushi(2001)',
#  '22.Saving Private Ryan(1998)',
#  '23.The Green Mile(1999)',
#  '24.La vita è bella(1997)',
#  '25.Se7en(1995)',
#  '26.Terminator 2: Judgment Day(1991)',
#  '27.The Silence of the Lambs(1991)',
#  '28.Star Wars(1977)',
# ...

# %%
year= []
for i in bs.find_all('span',class_='lister-item-year text-muted unbold'):
    year.append(i.text)

# %%
year
# Out:
# ['(1994)',
#  '(1972)',
#  '(2008)',
#  '(2003)',
#  '(1993)',
#  '(1974)',
#  '(1957)',
#  '(1994)',
#  '(2010)',
#  '(2002)',
#  '(1999)',
#  '(2001)',
#  '(1994)',
#  '(1966)',
#  '(1999)',
#  '(1990)',
#  '(1980)',
#  '(1975)',
#  '(2014)',
#  '(2002)',
#  '(2001)',
#  '(1998)',
#  '(1999)',
#  '(1997)',
#  '(1995)',
#  '(1991)',
#  '(1991)',
#  '(1977)',
#  '(1962)',
#  '(1954)',
#  '(1946)',
#  '(2019)',
#  '(2014)',
#  '(2011)',
#  '(2006)',
#  '(2006)',
#  '(2002)',
#  '(2000)',
#  '(1998)',
#  '(1995)',
#  '(1994)',
#  '(1994)',
#  '(1988)',
#  '(1988)',
#  '(1985)',
#  '(1979)',
#  '(1979)',
#  '(1968)',
#  '(1960)',
#  '(1954)']

# %%
len(year)
# Out:
# 50

# %%
ratings=[]
for i in bs.find_all('div', class_='inline-block ratings-imdb-rating'):
    ratings.append(i.text.split('|')[0])

# %%
ratings = [i.replace('\n','') for i in ratings]

# %%
df2 = pd.DataFrame({'title':titles,'year of release':year,'rating':ratings})

# %%
df2
# Out:
#                                                 title year of release rating
# 0                    1.The Shawshank Redemption(1994)          (1994)    9.3
# 1                               2.The Godfather(1972)          (1972)    9.2
# 2                             3.The Dark Knight(2008)          (2008)    9.0
# 3   4.The Lord of the Rings: The Return of the Kin...          (2003)    9.0
# 4                            5.Schindler's List(1993)          (1993)    9.0
# 5                       6.The Godfather Part II(1974)          (1974)    9.0
# 6                                7.12 Angry Men(1957)          (1957)    9.0
# 7                                8.Pulp Fiction(1994)          (1994)    8.9
# 8                                   9.Inception(2010)          (2010)    8.8
# 9      10.The Lord of the Rings: The Two Towers(2002)          (2002)    8.8
# 10                                11.Fight Club(1999)          (1999)    8.8
# ...

# %%
df2.shape
# Out:
# (50, 3)

# %% [markdown]
# ## IMDB TOP 100 INDIAN FILMS

# %%
web3 = requests.get('https://www.imdb.com/list/ls561664100/')

# %%
web3
# Out:
# <Response [200]>

# %%
bs = BeautifulSoup(web3.content)

# %%
name=[]
for i in bs.find_all('h3',class_='lister-item-header'):
    name.append(i.text.split('|')[0])

# %%
name
# Out:
# ['\n1.\nGangs of Wasseypur\n(2012)\n',
#  '\n2.\nMasaan\n(2015)\n',
#  '\n3.\nShip of Theseus\n(2012)\n',
#  '\n4.\nBlack Friday\n(2004)\n',
#  '\n5.\nUdaan\n(2010)\n',
#  '\n6.\nSardar Udham\n(2021)\n',
#  '\n7.\nHaider\n(2014)\n',
#  '\n8.\nThe Lunchbox\n(2013)\n',
#  '\n9.\nOmkara\n(2006)\n',
#  '\n10.\n3 Idiots\n(2009)\n',
#  '\n11.\nZindagi Na Milegi Dobara\n(2011)\n',
#  '\n12.\nSwades: We, the People\n(2004)\n',
#  '\n13.\nShahid\n(2012)\n',
#  '\n14.\nAnkhon Dekhi\n(2013)\n',
#  '\n15.\nAligarh\n(2015)\n',
#  '\n16.\nAndhadhun\n(2018)\n',
#  '\n17.\nMaqbool\n(2003)\n',
#  '\n18.\nTaare Zameen Par\n(2007)\n',
#  '\n19.\nSonchiriya\n(2019)\n',
#  '\n20.\nGulaal\n(2009)\n',
#  '\n21.\nRaincoat\n(2004)\n',
#  '\n22.\nLootera\n(I) (2013)\n',
#  '\n23.\nLagaan: Once Upon a Time in India\n(2001)\n',
#  '\n24.\nKhosla Ka Ghosla!\n(2006)\n',
#  '\n25.\nDangal\n(2016)\n',
#  '\n26.\nA Death in the Gunj\n(2016)\n',
#  '\n27.\nTalvar\n(2015)\n',
#  '\n28.\nDev.D\n(2009)\n',
# ...

# %%
name = [i.replace('\n','') for i in name]

# %%
name
# Out:
# ['1.Gangs of Wasseypur(2012)',
#  '2.Masaan(2015)',
#  '3.Ship of Theseus(2012)',
#  '4.Black Friday(2004)',
#  '5.Udaan(2010)',
#  '6.Sardar Udham(2021)',
#  '7.Haider(2014)',
#  '8.The Lunchbox(2013)',
#  '9.Omkara(2006)',
#  '10.3 Idiots(2009)',
#  '11.Zindagi Na Milegi Dobara(2011)',
#  '12.Swades: We, the People(2004)',
#  '13.Shahid(2012)',
#  '14.Ankhon Dekhi(2013)',
#  '15.Aligarh(2015)',
#  '16.Andhadhun(2018)',
#  '17.Maqbool(2003)',
#  '18.Taare Zameen Par(2007)',
#  '19.Sonchiriya(2019)',
#  '20.Gulaal(2009)',
#  '21.Raincoat(2004)',
#  '22.Lootera(I) (2013)',
#  '23.Lagaan: Once Upon a Time in India(2001)',
#  '24.Khosla Ka Ghosla!(2006)',
#  '25.Dangal(2016)',
#  '26.A Death in the Gunj(2016)',
#  '27.Talvar(2015)',
#  '28.Dev.D(2009)',
#  '29.Johnny Gaddaar(2007)',
#  '30.Ugly(2013)',
#  '31.Kahaani(2012)',
#  '32.Badhaai Do(2022)',
#  '33.Tumbbad(2018)',
#  '34.Hera Pheri(2000)',
#  '35.Drishyam(2015)',
#  '36.Veer-Zaara(2004)',
#  '37.Barfi!(2012)',
# ...

# %%
rel_year=[]
for i in bs.find_all('span',class_='lister-item-year text-muted unbold'):
    rel_year.append(i.text.split('|')[0])

# %%
rel_year
# Out:
# ['(2012)',
#  '(2015)',
#  '(2012)',
#  '(2004)',
#  '(2010)',
#  '(2021)',
#  '(2014)',
#  '(2013)',
#  '(2006)',
#  '(2009)',
#  '(2011)',
#  '(2004)',
#  '(2012)',
#  '(2013)',
#  '(2015)',
#  '(2018)',
#  '(2003)',
#  '(2007)',
#  '(2019)',
#  '(2009)',
#  '(2004)',
#  '(I) (2013)',
#  '(2001)',
#  '(2006)',
#  '(2016)',
#  '(2016)',
#  '(2015)',
#  '(2009)',
#  '(2007)',
#  '(2013)',
#  '(2012)',
#  '(2022)',
#  '(2018)',
#  '(2000)',
#  '(2015)',
#  '(2004)',
#  '(2012)',
#  '(I) (2014)',
#  '(2006)',
#  '(2006)',
#  '(2003)',
#  '(2007)',
#  '(I) (2018)',
#  '(2013)',
#  '(II) (2018)',
#  '(2005)',
#  '(2007)',
#  '(2015)',
#  '(2017)',
#  '(2016)',
#  '(2014)',
#  '(2016)',
#  '(2017)',
#  '(2012)',
#  '(2017)',
#  '(I) (2002)',
#  '(2014)',
#  '(2011)',
#  '(2001)',
#  '(III) (2016)',
#  '(2007)',
#  '(2003)',
#  '(2015)',
#  '(2012)',
#  '(2001)',
#  '(2007)',
#  '(2002)',
#  '(I) (2005)',
#  '(2019)',
#  '(2011)',
#  '(2008)',
#  '(2007)',
#  '(2015)',
#  '(2022)',
# ...

# %%
rel_year = [i.replace('(I) ','') for i in rel_year]
rel_year = [i.replace('(II) ','') for i in rel_year]
rel_year = [i.replace('(III) ','') for i in rel_year]
rel_year = [i.replace('(XVII) ','') for i in rel_year]

# %%
rel_year
# Out:
# ['(2012)',
#  '(2015)',
#  '(2012)',
#  '(2004)',
#  '(2010)',
#  '(2021)',
#  '(2014)',
#  '(2013)',
#  '(2006)',
#  '(2009)',
#  '(2011)',
#  '(2004)',
#  '(2012)',
#  '(2013)',
#  '(2015)',
#  '(2018)',
#  '(2003)',
#  '(2007)',
#  '(2019)',
#  '(2009)',
#  '(2004)',
#  '(2013)',
#  '(2001)',
#  '(2006)',
#  '(2016)',
#  '(2016)',
#  '(2015)',
#  '(2009)',
#  '(2007)',
#  '(2013)',
#  '(2012)',
#  '(2022)',
#  '(2018)',
#  '(2000)',
#  '(2015)',
#  '(2004)',
#  '(2012)',
#  '(2014)',
#  '(2006)',
#  '(2006)',
#  '(2003)',
#  '(2007)',
#  '(2018)',
#  '(2013)',
#  '(2018)',
#  '(2005)',
#  '(2007)',
#  '(2015)',
#  '(2017)',
#  '(2016)',
#  '(2014)',
#  '(2016)',
#  '(2017)',
#  '(2012)',
#  '(2017)',
#  '(2002)',
#  '(2014)',
#  '(2011)',
#  '(2001)',
#  '(2016)',
#  '(2007)',
#  '(2003)',
#  '(2015)',
#  '(2012)',
#  '(2001)',
#  '(2007)',
#  '(2002)',
#  '(2005)',
#  '(2019)',
#  '(2011)',
#  '(2008)',
#  '(2007)',
#  '(2015)',
#  '(2022)',
#  '(2003)',
#  '(2011)',
# ...

# %%
len(rel_year)
# Out:
# 100

# %%
rating1= []
for i in bs.find_all('div',class_='ipl-rating-star small'):
    rating1.append(i.text.split('|')[0])

# %%
rating1
# Out:
# ['\n\n\n\n\n\n\n\n8.2\n',
#  '\n\n\n\n\n\n\n\n8.1\n',
#  '\n\n\n\n\n\n\n\n8\n',
#  '\n\n\n\n\n\n\n\n8.4\n',
#  '\n\n\n\n\n\n\n\n8.1\n',
#  '\n\n\n\n\n\n\n\n8.4\n',
#  '\n\n\n\n\n\n\n\n8\n',
#  '\n\n\n\n\n\n\n\n7.8\n',
#  '\n\n\n\n\n\n\n\n8.1\n',
#  '\n\n\n\n\n\n\n\n8.4\n',
#  '\n\n\n\n\n\n\n\n8.2\n',
#  '\n\n\n\n\n\n\n\n8.2\n',
#  '\n\n\n\n\n\n\n\n8.2\n',
#  '\n\n\n\n\n\n\n\n7.9\n',
#  '\n\n\n\n\n\n\n\n7.8\n',
#  '\n\n\n\n\n\n\n\n8.2\n',
#  '\n\n\n\n\n\n\n\n8\n',
#  '\n\n\n\n\n\n\n\n8.4\n',
#  '\n\n\n\n\n\n\n\n7.9\n',
#  '\n\n\n\n\n\n\n\n8\n',
#  '\n\n\n\n\n\n\n\n7.7\n',
#  '\n\n\n\n\n\n\n\n7.4\n',
#  '\n\n\n\n\n\n\n\n8.1\n',
#  '\n\n\n\n\n\n\n\n8.3\n',
#  '\n\n\n\n\n\n\n\n8.3\n',
#  '\n\n\n\n\n\n\n\n7.4\n',
#  '\n\n\n\n\n\n\n\n8.1\n',
#  '\n\n\n\n\n\n\n\n7.9\n',
#  '\n\n\n\n\n\n\n\n7.9\n',
#  '\n\n\n\n\n\n\n\n7.9\n',
#  '\n\n\n\n\n\n\n\n8.1\n',
#  '\n\n\n\n\n\n\n\n7\n',
#  '\n\n\n\n\n\n\n\n8.2\n',
#  '\n\n\n\n\n\n\n\n8.1\n',
#  '\n\n\n\n\n\n\n\n8.2\n',
#  '\n\n\n\n\n\n\n\n7.8\n',
# ...

# %%
len(rating1)
# Out:
# 100

# %%
rating1=[i.replace('\n','') for i in rating1]

# %%
rating1
# Out:
# ['8.2',
#  '8.1',
#  '8',
#  '8.4',
#  '8.1',
#  '8.4',
#  '8',
#  '7.8',
#  '8.1',
#  '8.4',
#  '8.2',
#  '8.2',
#  '8.2',
#  '7.9',
#  '7.8',
#  '8.2',
#  '8',
#  '8.4',
#  '7.9',
#  '8',
#  '7.7',
#  '7.4',
#  '8.1',
#  '8.3',
#  '8.3',
#  '7.4',
#  '8.1',
#  '7.9',
#  '7.9',
#  '7.9',
#  '8.1',
#  '7',
#  '8.2',
#  '8.1',
#  '8.2',
#  '7.8',
#  '8.1',
#  '7.6',
#  '8.1',
#  '8',
#  '7.9',
#  '8.1',
#  '7.7',
#  '8.1',
#  '7.5',
#  '8.1',
#  '7.9',
#  '7.6',
#  '8',
#  '7.7',
#  '7.5',
#  '7.7',
#  '7.6',
#  '8.2',
#  '8',
#  '7.5',
#  '8.1',
#  '7.8',
#  '8.1',
#  '8.1',
#  '7.3',
#  '7.9',
#  '7.5',
#  '7.8',
#  '7.3',
#  '8.2',
#  '8',
#  '7.7',
#  '8.1',
#  '7.7',
#  '7.7',
#  '6.7',
#  '8.1',
#  '7.4',
#  '8.1',
#  '7.5',
#  '7.4',
#  '7.3',
#  '7.7',
#  '7',
#  '8.1',
#  '7.3',
#  '7.8',
#  '7.9',
#  '7.9',
#  '7',
#  '8.2',
#  '7.6',
#  '7.7',
#  '7.4',
#  '7.6',
#  '7',
#  '7',
#  '7.6',
#  '7.8',
#  '7.2',
#  '7.8',
#  '8.1',
#  '7.2',
#  '7.5']

# %%
df=pd.DataFrame({'name':name,'year':rel_year,'rating':rating1})

# %%
df
# Out:
#                                   name    year rating
# 0           1.Gangs of Wasseypur(2012)  (2012)    8.2
# 1                       2.Masaan(2015)  (2015)    8.1
# 2              3.Ship of Theseus(2012)  (2012)      8
# 3                 4.Black Friday(2004)  (2004)    8.4
# 4                        5.Udaan(2010)  (2010)    8.1
# ..                                 ...     ...    ...
# 95             96.Eeb Allay Ooo!(2019)  (2019)    7.2
# 96                97.Dasvidaniya(2008)  (2008)    7.8
# 97                98.A Wednesday(2008)  (2008)    8.1
# 98  99.LSD: Love, Sex Aur Dhokha(2010)  (2010)    7.2
# 99            100.Trapped(XVII) (2016)  (2016)    7.5
#
# [100 rows x 3 columns]

# %% [markdown]
# ## President of India

# %%
web3 = requests.get('https://presidentofindia.nic.in/former-presidents.htm')

# %%
bs = BeautifulSoup(web3.content)

# %%
pres_name=[]

# %%
for i in bs.find_all('h3',class_='presidentListing'):
    pres_name.append(i.text.split('|')[0])

# %%
pres_name
# Out:
# []

# %%
president=[]
for i in bs.find_all('div',class_='presidentListing'):
    president.append(i.text.split('|'))

# %%
president
# Out:
# [['\nShri Ram Nath Kovind (birth - 1945)\nTerm of Office: 25 July, 2017 to 25 July, 2022 \nhttps://ramnathkovind.nic.in\n'],
#  ['\nShri Pranab Mukherjee (1935-2020)\nTerm of Office: 25 July, 2012 to 25 July, 2017 \nhttp://pranabmukherjee.nic.in\n'],
#  ['\nSmt Pratibha Devisingh Patil (birth - 1934)\nTerm of Office: 25 July, 2007 to 25 July, 2012 \nhttp://pratibhapatil.nic.in\n'],
#  ['\nDR. A.P.J. Abdul Kalam (1931-2015)\nTerm of Office: 25 July, 2002 to 25 July, 2007 \nhttp://abdulkalam.nic.in\n'],
#  ['\nShri K. R. Narayanan (1920 - 2005)\nTerm of Office: 25 July, 1997 to 25 July, 2002 \n'],
#  ['\nDr Shankar Dayal Sharma (1918-1999)\nTerm of Office: 25 July, 1992 to 25 July, 1997 \n'],
#  ['\nShri R Venkataraman (1910-2009)\nTerm of Office: 25 July, 1987 to 25 July, 1992 \n'],
#  ['\nGiani Zail Singh (1916-1994)\nTerm of Office: 25 July, 1982 to 25 July, 1987 \n'],
#  ['\nShri Neelam Sanjiva Reddy (1913-1996)\nTerm of Office: 25 July, 1977 to 25 July, 1982 \n'],
# ...

# %%
president
# Out:
# [['\nShri Ram Nath Kovind (birth - 1945)\nTerm of Office: 25 July, 2017 to 25 July, 2022 \nhttps://ramnathkovind.nic.in\n'],
#  ['\nShri Pranab Mukherjee (1935-2020)\nTerm of Office: 25 July, 2012 to 25 July, 2017 \nhttp://pranabmukherjee.nic.in\n'],
#  ['\nSmt Pratibha Devisingh Patil (birth - 1934)\nTerm of Office: 25 July, 2007 to 25 July, 2012 \nhttp://pratibhapatil.nic.in\n'],
#  ['\nDR. A.P.J. Abdul Kalam (1931-2015)\nTerm of Office: 25 July, 2002 to 25 July, 2007 \nhttp://abdulkalam.nic.in\n'],
#  ['\nShri K. R. Narayanan (1920 - 2005)\nTerm of Office: 25 July, 1997 to 25 July, 2002 \n'],
#  ['\nDr Shankar Dayal Sharma (1918-1999)\nTerm of Office: 25 July, 1992 to 25 July, 1997 \n'],
#  ['\nShri R Venkataraman (1910-2009)\nTerm of Office: 25 July, 1987 to 25 July, 1992 \n'],
#  ['\nGiani Zail Singh (1916-1994)\nTerm of Office: 25 July, 1982 to 25 July, 1987 \n'],
#  ['\nShri Neelam Sanjiva Reddy (1913-1996)\nTerm of Office: 25 July, 1977 to 25 July, 1982 \n'],
# ...

# %%
import numpy as np

# %%
np.savetxt("presidentofindia.csv", 
           president,
           delimiter =", ", 
           fmt ='% s')

# %%
file=pd.read_csv('presidentofindia.csv',header=0,names=['name','term'])

# %%
df4= pd.DataFrame(file)

# %%
df4
# Out:
#                                            name  \
# 0             Shri Pranab Mukherjee (1935-2020)
# 1   Smt Pratibha Devisingh Patil (birth - 1934)
# 2            DR. A.P.J. Abdul Kalam (1931-2015)
# 3            Shri K. R. Narayanan (1920 - 2005)
# 4           Dr Shankar Dayal Sharma (1918-1999)
# 5               Shri R Venkataraman (1910-2009)
# 6                  Giani Zail Singh (1916-1994)
# 7         Shri Neelam Sanjiva Reddy (1913-1996)
# 8          Dr. Fakhruddin Ali Ahmed (1905-1977)
# 9      Shri Varahagiri Venkata Giri (1894-1980)
# 10                 Dr. Zakir Husain (1897-1969)
# 11     Dr. Sarvepalli Radhakrishnan (1888-1975)
# 12              Dr. Rajendra Prasad (1884-1963)
#
#                                                  term
# 0                       25 July 2012 to 25 July 2017
# 1                       25 July 2007 to 25 July 2012
# 2                        25 July 2002 to 25 July 2007
# 3                       25 July 1997 to 25 July 2002
# ...

# %% [markdown]
# ## ICC

# %%
web = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')

# %%
web
# Out:
# <Response [200]>

# %%
bs= BeautifulSoup(web.content)

# %%
first_team=[]
for i in bs.find_all('span',class_='u-hide-phablet'):
    first_team.append(i.text.split('|')[0])

# %%
first_team
# Out:
# ['New Zealand',
#  'England',
#  'Australia',
#  'India',
#  'Pakistan',
#  'South Africa',
#  'Bangladesh',
#  'Sri Lanka',
#  'Afghanistan',
#  'West Indies',
#  'Ireland',
#  'Scotland',
#  'Zimbabwe',
#  'Namibia',
#  'Netherlands',
#  'Oman',
#  'UAE',
#  'United States',
#  'Nepal',
#  'Papua New Guinea']

# %%
matches=[]
for i in bs.find_all('td',class_='rankings-block__banner--matches'):
    matches.append(i.text.split('|')[0])

# %%
matches
# Out:
# ['23']

# %%
matches2=[]
for i in bs.find_all('td',class_='table-body__cell u-center-text'):
    matches2.append(i.text.split('|')[0])

# %%
matches2
# Out:
# ['30',
#  '3,400',
#  '32',
#  '3,572',
#  '35',
#  '3,866',
#  '22',
#  '2,354',
#  '24',
#  '2,392',
#  '30',
#  '2,753',
#  '30',
#  '2,677',
#  '19',
#  '1,380',
#  '41',
#  '2,902',
#  '23',
#  '1,214',
#  '27',
#  '1,254',
#  '26',
#  '1,098',
#  '23',
#  '808',
#  '21',
#  '673',
#  '30',
#  '919',
#  '25',
#  '693',
#  '31',
#  '821',
#  '25',
#  '476',
#  '30',
#  '128']

# %%
matches
# Out:
# ['23']

# %%
matches3 = ''
i=0

while(i < len(matches2)):
    if(i % 2 == 0):
        matches3 = matches3 +','+ matches2[i]
    i = i + 1

# %%
matches3
# Out:
# ',30,32,35,22,24,30,30,19,41,23,27,26,23,21,30,25,31,25,30'

# %%
matches00=list(matches3)

# %%
#matches3=matches3.remove(",")

# %%
points=[]
for i in bs.find_all('td',class_='rankings-block__banner--points'):
    points.append(i.text.split('|')[0])

# %%
points
# Out:
# ['2,670']

# %%
points2=[]
for i in bs.find_all('td',class_='table-body__cell u-center-text'):
    points2.append(i.text.split('|')[0])

# %%
points2
# Out:
# ['30',
#  '3,400',
#  '32',
#  '3,572',
#  '35',
#  '3,866',
#  '22',
#  '2,354',
#  '24',
#  '2,392',
#  '30',
#  '2,753',
#  '30',
#  '2,677',
#  '19',
#  '1,380',
#  '41',
#  '2,902',
#  '23',
#  '1,214',
#  '27',
#  '1,254',
#  '26',
#  '1,098',
#  '23',
#  '808',
#  '21',
#  '673',
#  '30',
#  '919',
#  '25',
#  '693',
#  '31',
#  '821',
#  '25',
#  '476',
#  '30',
#  '128']

# %%
new_points = [i.replace(",","") for i in points2]

# %%
new_points
# Out:
# ['30',
#  '3400',
#  '32',
#  '3572',
#  '35',
#  '3866',
#  '22',
#  '2354',
#  '24',
#  '2392',
#  '30',
#  '2753',
#  '30',
#  '2677',
#  '19',
#  '1380',
#  '41',
#  '2902',
#  '23',
#  '1214',
#  '27',
#  '1254',
#  '26',
#  '1098',
#  '23',
#  '808',
#  '21',
#  '673',
#  '30',
#  '919',
#  '25',
#  '693',
#  '31',
#  '821',
#  '25',
#  '476',
#  '30',
#  '128']

# %%
points4 = ''
i=0

while(i < len(new_points)):
    if(i % 2 == 1):
        points4 = points4 +','+ new_points[i]
    i = i + 1

# %%
points4
# Out:
# ',3400,3572,3866,2354,2392,2753,2677,1380,2902,1214,1254,1098,808,673,919,693,821,476,128'

# %%
ratings=[]
for i in bs.find_all('td',class_='rankings-block__banner--rating u-text-right'):
    ratings.append(i.text.split('|')[0])

# %%
ratings
# Out:
# ['\n                            116\n                            \n\n']

# %%
ratings=[i.replace('\n','') for i in ratings]

# %%
ratings
# Out:
# ['                            116                            ']

# %%
ratings=[i.replace(' ','') for i in ratings]

# %%
ratings
# Out:
# ['116']

# %%
trating=[]
for i in bs.find_all('td',class_='table-body__cell u-text-right rating'):
    trating.append(i.text.split('|')[0])

# %%
trating
# Out:
# ['113',
#  '112',
#  '110',
#  '107',
#  '100',
#  '92',
#  '89',
#  '73',
#  '71',
#  '53',
#  '46',
#  '42',
#  '35',
#  '32',
#  '31',
#  '28',
#  '26',
#  '19',
#  '4']

# %%
mtch = list(matches3.split(",")) 
print(mtch)
# Out:
# ['', '30', '32', '35', '22', '24', '30', '30', '19', '41', '23', '27', '26', '23', '21', '30', '25', '31', '25', '30']

# %%
len(mtch)
# Out:
# 20

# %%
del mtch[0]

# %%
mtch
# Out:
# ['30',
#  '32',
#  '35',
#  '22',
#  '24',
#  '30',
#  '30',
#  '19',
#  '41',
#  '23',
#  '27',
#  '26',
#  '23',
#  '21',
#  '30',
#  '25',
#  '31',
#  '25',
#  '30']

# %%
pts = list(points4.split(",")) 
print(pts)
# Out:
# ['', '3400', '3572', '3866', '2354', '2392', '2753', '2677', '1380', '2902', '1214', '1254', '1098', '808', '673', '919', '693', '821', '476', '128']

# %%
del pts[0]

# %%
df=pd.DataFrame({'match':mtch,'points':pts,'ratings':trating})

# %%
df
# Out:
#    match points ratings
# 0     30   3400     113
# 1     32   3572     112
# 2     35   3866     110
# 3     22   2354     107
# 4     24   2392     100
# 5     30   2753      92
# 6     30   2677      89
# 7     19   1380      73
# 8     41   2902      71
# 9     23   1214      53
# 10    27   1254      46
# 11    26   1098      42
# 12    23    808      35
# 13    21    673      32
# 14    30    919      31
# 15    25    693      28
# 16    31    821      26
# 17    25    476      19
# 18    30    128       4

# %% [markdown]
# # Top 10 ODI Batsman

# %%
web= requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')

# %%
web
# Out:
# <Response [200]>

# %%
bs= BeautifulSoup(web.content)

# %%
player1 = []
for i in bs.find_all('div',class_='rankings-block__banner--nationality'):
    player1.append(i.text.split('|')[0])

# %%
player1
# Out:
# ['\n\nPAK\n                            890\n',
#  '\n\nNZ\n                            760\n',
#  '\n\nBAN\n                            372\n',
#  '\n\nPAK\n                            890\n',
#  '\n\nNZ\n                            760\n',
#  '\n\nBAN\n                            372\n']

# %%
player=player1[0]

# %%
player = list(player.split(",")) 
print(player)
# Out:
# ['\n\nPAK\n                            890\n']

# %%
player=[i.replace('\n','') for i in player]

# %%
player
# Out:
# ['PAK                            890']

# %%
player=[i.replace('890','') for i in player]

# %%
player
# Out:
# ['PAK                            ']

# %%
player=[i.replace(' ','') for i in player]

# %%
player
# Out:
# ['PAK']

# %%
players = []
for i in bs.find_all('span',class_='table-body__logo-text'):
    players.append(i.text.split('|')[0])

# %%
players
# Out:
# ['PAK',
#  'SA',
#  'SA',
#  'AUS',
#  'AUS',
#  'ENG',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'AUS',
#  'PAK',
#  'NZ',
#  'AUS',
#  'BAN',
#  'AFG',
#  'BAN',
#  'AFG',
#  'AFG',
#  'AFG',
#  'NZ',
#  'ZIM',
#  'OMA',
#  'BAN',
#  'SL',
#  'PNG',
#  'ENG',
#  'PAK',
#  'SA',
#  'SA',
#  'AUS',
#  'AUS',
#  'ENG',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'AUS',
#  'PAK',
#  'NZ',
#  'AUS',
#  'BAN',
#  'AFG',
#  'BAN',
#  'AFG',
#  'AFG',
#  'AFG',
#  'NZ',
#  'ZIM',
#  'OMA',
#  'BAN',
#  'SL',
#  'PNG',
#  'ENG']

# %%
len(players)
# Out:
# 54

# %%
player2=[]

# %%
player2.extend(player)

# %%
player2.extend(players)

# %%
player2
# Out:
# ['PAK',
#  'PAK',
#  'SA',
#  'SA',
#  'AUS',
#  'AUS',
#  'ENG',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'AUS',
#  'PAK',
#  'NZ',
#  'AUS',
#  'BAN',
#  'AFG',
#  'BAN',
#  'AFG',
#  'AFG',
#  'AFG',
#  'NZ',
#  'ZIM',
#  'OMA',
#  'BAN',
#  'SL',
#  'PNG',
#  'ENG',
#  'PAK',
#  'SA',
#  'SA',
#  'AUS',
#  'AUS',
#  'ENG',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'AUS',
#  'PAK',
#  'NZ',
#  'AUS',
#  'BAN',
#  'AFG',
#  'BAN',
#  'AFG',
#  'AFG',
#  'AFG',
#  'NZ',
#  'ZIM',
#  'OMA',
#  'BAN',
#  'SL',
#  'PNG',
#  'ENG']

# %%
player3= player2[:10]

# %%
player3
# Out:
# ['PAK', 'PAK', 'SA', 'SA', 'AUS', 'AUS', 'ENG', 'IND', 'IND', 'NZ']

# %%
len(player3)
# Out:
# 10

# %%
ratings = []
for i in bs.find_all('td',class_='table-body__cell u-text-right rating'):
    ratings.append(i.text.split('|')[0])

# %%
ratings
# Out:
# ['779',
#  '766',
#  '759',
#  '747',
#  '719',
#  '710',
#  '707',
#  '704',
#  '701',
#  '727',
#  '665',
#  '661',
#  '656',
#  '655',
#  '655',
#  '650',
#  '640',
#  '635',
#  '312',
#  '273',
#  '267',
#  '261',
#  '238',
#  '238',
#  '235',
#  '233',
#  '222',
#  '779',
#  '766',
#  '759',
#  '747',
#  '719',
#  '710',
#  '707',
#  '704',
#  '701',
#  '727',
#  '665',
#  '661',
#  '656',
#  '655',
#  '655',
#  '650',
#  '640',
#  '635',
#  '312',
#  '273',
#  '267',
#  '261',
#  '238',
#  '238',
#  '235',
#  '233',
#  '222']

# %%
ratings=ratings[:10]

# %%
len(ratings)
# Out:
# 10

# %%
df = pd.DataFrame({'country':player3,'ratings':ratings})

# %%
df
# Out:
#   country ratings
# 0     PAK     779
# 1     PAK     766
# 2      SA     759
# 3      SA     747
# 4     AUS     719
# 5     AUS     710
# 6     ENG     707
# 7     IND     704
# 8     IND     701
# 9      NZ     727

# %% [markdown]
# # Top 10 ODI Bowlers

# %%
web = requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi")

# %%
web
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(web.content,"html.parser")
print(soup.prettify())

# %%
scraped_player1 = soup.find_all('div',class_="rankings-block__banner--nationality")
scraped_player1
# Out:
# [<div class="rankings-block__banner--nationality">
#  <div class="flag-15 PAK"></div>
#  <span class="rankings-block__banner--nation"></span>PAK
#  <div class="rankings-block__banner--rating">890</div>
#  </div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 NZ"></div>
#  <span class="rankings-block__banner--nation"></span>NZ
#  <div class="rankings-block__banner--rating">752</div>
#  </div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 BAN"></div>
#  <span class="rankings-block__banner--nation"></span>BAN
#  <div class="rankings-block__banner--rating">389</div>
#  </div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 PAK"></div>
#  <span class="rankings-block__banner--nation"></span>PAK
#  <div class="rankings-block__banner--rating">890</div>
#  </div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 NZ"></div>
# ...

# %%
player2 = []
for play in scraped_player1:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    player2.append(play)
player2
# Out:
# ['PAK890', 'NZ752', 'BAN389', 'PAK890', 'NZ752', 'BAN389']

# %%
player=player2[1]

# %%
player
# Out:
# 'NZ752'

# %%
player= list(player.split(','))

# %%
player
# Out:
# ['NZ752']

# %%
player1=[i.replace('752','') for i in player]

# %%
player1
# Out:
# ['NZ']

# %%
# 10-19
scraped_players = soup.find_all('span',class_="table-body__logo-text")
scraped_players
# Out:
# [<span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">PAK</span>,
#  <span class="table-body__logo-text">AFG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">AFG</span>,
#  <span class="table-body__logo-text">AFG</span>,
# ...

# %%
player3 = []
for play in scraped_players[10:19]:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    player3.append(play)
print(player3)
# Out:
# ['AUS', 'NZ', 'PAK', 'AFG', 'AUS', 'BAN', 'BAN', 'AFG', 'AFG']

# %%
bowl_country = []

# %%
bowl_country.extend(player1)

# %%
bowl_country.extend(player3)

# %%
bowl_country
# Out:
# ['NZ', 'AUS', 'NZ', 'PAK', 'AFG', 'AUS', 'BAN', 'BAN', 'AFG', 'AFG']

# %%
scraped_rating = soup.find_all('div',class_="rankings-block__banner--rating")
scraped_rating
# Out:
# [<div class="rankings-block__banner--rating">890</div>,
#  <div class="rankings-block__banner--rating">752</div>,
#  <div class="rankings-block__banner--rating">389</div>,
#  <div class="rankings-block__banner--rating">890</div>,
#  <div class="rankings-block__banner--rating">752</div>,
#  <div class="rankings-block__banner--rating">389</div>]

# %%
brating = []
for play in scraped_rating[1]:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    brating.append(play)
print(brating)
# Out:
# ['752']

# %%
scraped_ratings = soup.find_all('td',class_="table-body__cell u-text-right rating")
scraped_ratings
# Out:
# [<td class="table-body__cell u-text-right rating">779</td>,
#  <td class="table-body__cell u-text-right rating">766</td>,
#  <td class="table-body__cell u-text-right rating">759</td>,
#  <td class="table-body__cell u-text-right rating">747</td>,
#  <td class="table-body__cell u-text-right rating">719</td>,
#  <td class="table-body__cell u-text-right rating">710</td>,
#  <td class="table-body__cell u-text-right rating">707</td>,
#  <td class="table-body__cell u-text-right rating">705</td>,
#  <td class="table-body__cell u-text-right rating">700</td>,
#  <td class="table-body__cell u-text-right rating">727</td>,
#  <td class="table-body__cell u-text-right rating">665</td>,
#  <td class="table-body__cell u-text-right rating">663</td>,
#  <td class="table-body__cell u-text-right rating">661</td>,
#  <td class="table-body__cell u-text-right rating">659</td>,
#  <td class="table-body__cell u-text-right rating">655</td>,
#  <td class="table-body__cell u-text-right rating">652</td>,
# ...

# %%
bratings = []
for play in scraped_ratings[10:19]:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    bratings.append(play)
print(bratings)
# Out:
# ['665', '663', '661', '659', '655', '652', '638', '637', '310']

# %%
bowl_ratings = []

# %%
bowl_ratings.extend(brating)

# %%
bowl_ratings.extend(bratings)

# %%
bowl_ratings
# Out:
# ['752', '665', '663', '661', '659', '655', '652', '638', '637', '310']

# %%
df = pd.DataFrame({'country':bowl_country,'ratings':bowl_ratings})

# %%
df
# Out:
#   country ratings
# 0      NZ     752
# 1     AUS     665
# 2      NZ     663
# 3     PAK     661
# 4     AFG     659
# 5     AUS     655
# 6     BAN     652
# 7     BAN     638
# 8     AFG     637
# 9     AFG     310

# %% [markdown]
# ## 10 ODI teams WOMEN

# %%
web = requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi")

# %%
web
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(web.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
scraped_wcountry = soup.find_all('span',class_="u-hide-phablet")
scraped_wcountry
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">Thailand</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Ireland</span>,
#  <span class="u-hide-phablet">Netherlands</span>,
#  <span class="u-hide-phablet">Zimbabwe</span>]

# %%
wcountry = []
for play in scraped_wcountry:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    wcountry.append(play)
print(wcountry)
# Out:
# ['Australia', 'England', 'South Africa', 'India', 'New Zealand', 'West Indies', 'Bangladesh', 'Thailand', 'Pakistan', 'Sri Lanka', 'Ireland', 'Netherlands', 'Zimbabwe']

# %%
scraped_wmatch = soup.find_all('td',class_="rankings-block__banner--matches")
scraped_wmatch
# Out:
# [<td class="rankings-block__banner--matches">18</td>]

# %%
wmatch = []
for play in scraped_wmatch:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    wmatch.append(play)
print(wmatch)
# Out:
# ['18']

# %%
scraped_wmatches = soup.find_all('td',class_="table-body__cell u-center-text")
scraped_wmatches
# Out:
# [<td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">3,342</td>,
#  <td class="table-body__cell u-center-text">26</td>,
#  <td class="table-body__cell u-center-text">3,098</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,820</td>,
#  <td class="table-body__cell u-center-text">25</td>,
#  <td class="table-body__cell u-center-text">2,553</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,535</td>,
#  <td class="table-body__cell u-center-text">13</td>,
#  <td class="table-body__cell u-center-text">983</td>,
#  <td class="table-body__cell u-center-text">8</td>,
#  <td class="table-body__cell u-center-text">572</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">1,519</td>,
#  <td class="table-body__cell u-center-text">8</td>,
# ...

# %%
wmatches = []
for play in scraped_wmatches:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    wmatches.append(play)
print(wmatches)
# Out:
# ['28', '3,342', '26', '3,098', '27', '2,820', '25', '2,553', '27', '2,535', '13', '983', '8', '572', '24', '1,519', '8', '353', '14', '548', '9', '0', '8', '0']

# %%
wmatches1 = ''
i=0

while(i < len(wmatches)):
    if(i % 2 == 0):
        wmatches1 = wmatches1 +','+ wmatches[i]
    i = i + 1

# %%
wmatches1
# Out:
# ',28,26,27,25,27,13,8,24,8,14,9,8'

# %%
wmatches2 = list(wmatches1.split(",")) 
print(wmatches2)
# Out:
# ['', '28', '26', '27', '25', '27', '13', '8', '24', '8', '14', '9', '8']

# %%
wmatches2.remove("")

# %%
wmatches2
# Out:
# ['28', '26', '27', '25', '27', '13', '8', '24', '8', '14', '9', '8']

# %%
len(wmatches2)
# Out:
# 12

# %%
wmatches = [i.replace(",","") for i in wmatches]
wmatches
# Out:
# ['28',
#  '3342',
#  '26',
#  '3098',
#  '27',
#  '2820',
#  '25',
#  '2553',
#  '27',
#  '2535',
#  '13',
#  '983',
#  '8',
#  '572',
#  '24',
#  '1519',
#  '8',
#  '353',
#  '14',
#  '548',
#  '9',
#  '0',
#  '8',
#  '0']

# %%
wpoints = ''
i=0

while(i < len(wmatches)):
    if(i % 2 == 1):
        wpoints = wpoints +','+ wmatches[i]
    i = i + 1

# %%
wpoints
# Out:
# ',3342,3098,2820,2553,2535,983,572,1519,353,548,0,0'

# %%
wpoints2= list(wpoints.split(','))

# %%
wpoints2
# Out:
# ['3342',
#  '3098',
#  '2820',
#  '2553',
#  '2535',
#  '983',
#  '572',
#  '1519',
#  '353',
#  '548',
#  '0',
#  '0']

# %%
len(wpoints2)
# Out:
# 12

# %%
scraped_wrating = soup.find_all('td',class_="rankings-block__banner--rating u-text-right")
scraped_wrating
# Out:
# [<td class="rankings-block__banner--rating u-text-right">
#                              170
#                              <span class="circle-branding circle-branding--top"></span>
#  <span class="circle-branding circle-branding--bottom"></span>
#  </td>]

# %%
wrating = []
for play in scraped_wrating:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    wrating.append(play)
print(wrating)
# Out:
# ['170']

# %%
scraped_wratings = soup.find_all('td',class_="table-body__cell u-text-right rating")
scraped_wratings
# Out:
# [<td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">104</td>,
#  <td class="table-body__cell u-text-right rating">102</td>,
#  <td class="table-body__cell u-text-right rating">94</td>,
#  <td class="table-body__cell u-text-right rating">76</td>,
#  <td class="table-body__cell u-text-right rating">72</td>,
#  <td class="table-body__cell u-text-right rating">63</td>,
#  <td class="table-body__cell u-text-right rating">44</td>,
#  <td class="table-body__cell u-text-right rating">39</td>,
#  <td class="table-body__cell u-text-right rating">0</td>,
#  <td class="table-body__cell u-text-right rating">0</td>]

# %%
wratings = []
for play in scraped_wratings:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    wratings.append(play)
print(wratings)
# Out:
# ['119', '119', '104', '102', '94', '76', '72', '63', '44', '39', '0', '0']

# %%
len(wratings)
# Out:
# 12

# %%
df = pd.DataFrame({'matches':wmatches2,'points':wpoints2,'ratings':wratings})
df
# Out:
#    matches points ratings
# 0       28   3342     119
# 1       26   3098     119
# 2       27   2820     104
# 3       25   2553     102
# 4       27   2535      94
# 5       13    983      76
# 6        8    572      72
# 7       24   1519      63
# 8        8    353      44
# 9       14    548      39
# 10       9      0       0
# 11       8      0       0

# %%
df=df[:10][:]

# %%
df
# Out:
#   matches points ratings
# 0      28   3342     119
# 1      26   3098     119
# 2      27   2820     104
# 3      25   2553     102
# 4      27   2535      94
# 5      13    983      76
# 6       8    572      72
# 7      24   1519      63
# 8       8    353      44
# 9      14    548      39

# %% [markdown]
# ## Top 10 ODI Batting (Women)

# %%
web = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi")

# %%
web
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(web.content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Women's ODI Player Rankings | ICC" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC Women's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %%
scraped_player = soup.find_all('div',class_="rankings-block__banner--nationality")
scraped_player
# Out:
# [<div class="rankings-block__banner--nationality">
#  <div class="flag-15 AUS"></div>
#  <span class="rankings-block__banner--nation"></span>AUS
#  <div class="rankings-block__banner--rating">785</div>
#  </div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 ENG"></div>
#  <span class="rankings-block__banner--nation"></span>ENG
#  <div class="rankings-block__banner--rating">751</div>
#  </div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 AUS"></div>
#  <span class="rankings-block__banner--nation"></span>AUS
#  <div class="rankings-block__banner--rating">374</div>
#  </div>]

# %%
player1 = []
for play in scraped_player:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    player1.append(play)
print(player1)
# Out:
# ['AUS785', 'ENG751', 'AUS374']

# %%
player = player1[0]

# %%
player
# Out:
# 'AUS785'

# %%
player= list(player.split(','))

# %%
player
# Out:
# ['AUS785']

# %%
player2=[i.replace('785','') for i in player]

# %%
player2
# Out:
# ['AUS']

# %%
scraped_players = soup.find_all('td',class_="table-body__cell nationality-logo")
scraped_players
# Out:
# [<td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo AUS"></span>
#  <span class="table-body__logo-text">AUS</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo SA"></span>
#  <span class="table-body__logo-text">SA</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo ENG"></span>
#  <span class="table-body__logo-text">ENG</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="table-body__logo-text">IND</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo IND"></span>
#  <span class="table-body__logo-text">IND</span>
#  </td>,
#  <td class="table-body__cell nationality-logo">
#  <span class="flag-15 table-body_logo AUS"></span>
#  <span class="table-body__logo-text">AUS</span>
#  </td>,
# ...

# %%
bplayers = []
for play in scraped_players:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    bplayers.append(play)
print(bplayers)
# Out:
# ['AUS', 'SA', 'ENG', 'IND', 'IND', 'AUS', 'AUS', 'SL', 'NZ', 'AUS', 'AUS', 'SA', 'IND', 'WI', 'ENG', 'SA', 'IND', 'SA', 'WI', 'ENG', 'SA', 'NZ', 'IND', 'AUS', 'AUS', 'IND', 'ENG']

# %%
len(bplayers)
# Out:
# 27

# %%
bplayers=bplayers[:9]

# %%
bplayers
# Out:
# ['AUS', 'SA', 'ENG', 'IND', 'IND', 'AUS', 'AUS', 'SL', 'NZ']

# %%
len(bplayers)
# Out:
# 10

# %%
women_batsman_team=[]

# %%
women_batsman_team.extend(player2)
women_batsman_team.extend(bplayers)

# %%
women_batsman_team
# Out:
# ['AUS', 'AUS', 'SA', 'ENG', 'IND', 'IND', 'AUS', 'AUS', 'SL', 'NZ']

# %%
scraped_wrating = soup.find_all('div',class_="rankings-block__banner--rating")
scraped_wrating
# Out:
# [<div class="rankings-block__banner--rating">785</div>,
#  <div class="rankings-block__banner--rating">751</div>,
#  <div class="rankings-block__banner--rating">374</div>]

# %%
wrating1 = []
for play in scraped_wrating:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    wrating1.append(play)
print(wrating1)
# Out:
# ['785', '751', '374']

# %%
wrating1 = wrating1[:1]

# %%
wrating1
# Out:
# ['785']

# %%
scraped_wratings = soup.find_all('td',class_= "table-body__cell u-text-right rating")
scraped_wratings
# Out:
# [<td class="table-body__cell u-text-right rating">749</td>,
#  <td class="table-body__cell u-text-right rating">732</td>,
#  <td class="table-body__cell u-text-right rating">731</td>,
#  <td class="table-body__cell u-text-right rating">716</td>,
#  <td class="table-body__cell u-text-right rating">714</td>,
#  <td class="table-body__cell u-text-right rating">710</td>,
#  <td class="table-body__cell u-text-right rating">701</td>,
#  <td class="table-body__cell u-text-right rating">655</td>,
#  <td class="table-body__cell u-text-right rating">654</td>,
#  <td class="table-body__cell u-text-right rating">725</td>,
#  <td class="table-body__cell u-text-right rating">722</td>,
#  <td class="table-body__cell u-text-right rating">722</td>,
#  <td class="table-body__cell u-text-right rating">698</td>,
#  <td class="table-body__cell u-text-right rating">660</td>,
#  <td class="table-body__cell u-text-right rating">655</td>,
#  <td class="table-body__cell u-text-right rating">634</td>,
# ...

# %%
wrating2 = []
for play in scraped_wratings[0:9]:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    wrating2.append(play)
print(wrating2)
# Out:
# ['749', '732', '731', '716', '714', '710', '701', '655', '654']

# %%
wrating3=[]
wrating3.extend(wrating1)
wrating3.extend(wrating2)

# %%
wrating3
# Out:
# ['785', '749', '732', '731', '716', '714', '710', '701', '655', '654']

# %%
df = pd.DataFrame({'team':women_batsman_team,'ratings':wrating3})
df
# Out:
#   team ratings
# 0  AUS     785
# 1  AUS     749
# 2   SA     732
# 3  ENG     731
# 4  IND     716
# 5  IND     714
# 6  AUS     710
# 7  AUS     701
# 8   SL     655
# 9   NZ     654

# %% [markdown]
# ## Top 10 Womens ODI all-rounder

# %%
scraped_allr = soup.find_all('div',class_= "rankings-block__banner--nationality")
scraped_allr
# Out:
# [<div class="rankings-block__banner--nationality">
#  <div class="flag-15 AUS"></div>
#  <span class="rankings-block__banner--nation"></span>AUS
#  <div class="rankings-block__banner--rating">785</div>
#  </div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 ENG"></div>
#  <span class="rankings-block__banner--nation"></span>ENG
#  <div class="rankings-block__banner--rating">751</div>
#  </div>,
#  <div class="rankings-block__banner--nationality">
#  <div class="flag-15 AUS"></div>
#  <span class="rankings-block__banner--nation"></span>AUS
#  <div class="rankings-block__banner--rating">374</div>
#  </div>]

# %%
ar1 = []
for play in scraped_allr:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    ar1.append(play)
print(ar1)
# Out:
# ['AUS785', 'ENG751', 'AUS374']

# %%
ar1=list(ar1[2].split(","))

# %%
ar1
# Out:
# ['AUS374']

# %%
ar2,rar1 =[i.replace('374','') for i in ar1],[i.replace('AUS','') for i in ar1]

# %%
ar2
# Out:
# ['AUS']

# %%
rar1
# Out:
# ['374']

# %%
scraped_allrs = soup.find_all('span',class_= "table-body__logo-text")
scraped_allrs
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SL</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">WI</span>,
# ...

# %%
len(scraped_allrs)
# Out:
# 27

# %%
ars = []
for play in scraped_allrs[18:]:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    ars.append(play)
print(ars)
# Out:
# ['WI', 'ENG', 'SA', 'NZ', 'IND', 'AUS', 'AUS', 'IND', 'ENG']

# %%
scraped_rallrs = soup.find_all('td',class_= "table-body__cell u-text-right rating")
scraped_rallrs
# Out:
# [<td class="table-body__cell u-text-right rating">749</td>,
#  <td class="table-body__cell u-text-right rating">732</td>,
#  <td class="table-body__cell u-text-right rating">731</td>,
#  <td class="table-body__cell u-text-right rating">716</td>,
#  <td class="table-body__cell u-text-right rating">714</td>,
#  <td class="table-body__cell u-text-right rating">710</td>,
#  <td class="table-body__cell u-text-right rating">701</td>,
#  <td class="table-body__cell u-text-right rating">655</td>,
#  <td class="table-body__cell u-text-right rating">654</td>,
#  <td class="table-body__cell u-text-right rating">725</td>,
#  <td class="table-body__cell u-text-right rating">722</td>,
#  <td class="table-body__cell u-text-right rating">722</td>,
#  <td class="table-body__cell u-text-right rating">698</td>,
#  <td class="table-body__cell u-text-right rating">660</td>,
#  <td class="table-body__cell u-text-right rating">655</td>,
#  <td class="table-body__cell u-text-right rating">634</td>,
# ...

# %%
rars = []
for play in scraped_rallrs[18:]:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    rars.append(play)
print(rars)
# Out:
# ['373', '371', '349', '343', '322', '270', '246', '214', '205']

# %%
wallrounders = []
wallrounders.extend(ar2)
wallrounders.extend(ars)
print(wallrounders)
# Out:
# ['AUS', 'WI', 'ENG', 'SA', 'NZ', 'IND', 'AUS', 'AUS', 'IND', 'ENG']

# %%
wallrounders_rating = []
wallrounders_rating.extend(rar1)
wallrounders_rating.extend(rars)
print(wallrounders_rating)
# Out:
# ['374', '373', '371', '349', '343', '322', '270', '246', '214', '205']

# %%
df = pd.DataFrame({'teams':wallrounders,'ratings':wallrounders_rating})
df
# Out:
#   teams ratings
# 0   AUS     374
# 1    WI     373
# 2   ENG     371
# 3    SA     349
# 4    NZ     343
# 5   IND     322
# 6   AUS     270
# 7   AUS     246
# 8   IND     214
# 9   ENG     205

# %% [markdown]
# ## News Srapping Data

# %%
web = requests.get("https://www.cnbc.com/world/?region=world")

# %%
web
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(web.content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="https://schema.org/WebPage" lang="en" prefix="og=https://ogp.me/ns#">
#  <head>
#   <meta content="telephone=no" name="format-detection"/>
#   <style type="text/css">
# ...

# %%
scraped_headlines = soup.find_all('a',class_= "LatestNews-headline")
scraped_headlines
# Out:
# [<a class="LatestNews-headline" href="https://www.cnbc.com/2022/12/17/american-airlines-is-dropping-regional-carrier-mesa-citing-financial-and-operational-problems.html" title="American Airlines is dropping Mesa, citing financial and operational problems">American Airlines is dropping Mesa, citing financial and operational problems</a>,
#  <a class="LatestNews-headline" href="https://www.cnbc.com/2022/12/17/ftx-founder-sam-bankman-fried-will-not-contest-us-extradition-in-alleged-fraud-case-source-says.html" title="FTX founder Bankman-Fried will not contest U.S. extradition in alleged fraud case">FTX founder Bankman-Fried will not contest U.S. extradition in alleged fraud case</a>,
# ...

# %%
nheadlines = []
for play in scraped_headlines:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    nheadlines.append(play)
nheadlines
# Out:
# ['American Airlines is dropping Mesa, citing financial and operational problems',
#  'FTX founder Bankman-Fried will not contest U.S. extradition in alleged fraud case',
#  'These are the 10 biggest Christmas movies ever—and where you can watch them',
#  '10 self-care activities that will cost you little to no money',
#  'Rooftop solar: How homeowners can make sense of the climate finance',
#  "4 'red flags' that might mean your relationship is in trouble",
#  'Why annoying CAPTCHA is still big for Google and e-commerce in bot battle',
#  'The biggest barrier to starting a successful side hustle—and how to get past it',
#  'Airlines can price climate change into a plane ticket. Should you buy it?',
#  "'It never feels like you're out of poverty': Moses Storm mines his trauma for laughs",
#  '10 states where $1 million in retirement savings will run out the fastest',
#  'How cloud seeding can boosst rain and snowfall',
# ...

# %%
len(nheadlines)
# Out:
# 30

# %%
scraped_times = soup.find_all('time',class_= "LatestNews-timestamp")
scraped_times
# Out:
# [<time class="LatestNews-timestamp">6 Hours Ago</time>,
#  <time class="LatestNews-timestamp">7 Hours Ago</time>,
#  <time class="LatestNews-timestamp">13 Hours Ago</time>,
#  <time class="LatestNews-timestamp">13 Hours Ago</time>,
#  <time class="LatestNews-timestamp">15 Hours Ago</time>,
#  <time class="LatestNews-timestamp">15 Hours Ago</time>,
#  <time class="LatestNews-timestamp">15 Hours Ago</time>,
#  <time class="LatestNews-timestamp">15 Hours Ago</time>,
#  <time class="LatestNews-timestamp">16 Hours Ago</time>,
#  <time class="LatestNews-timestamp">16 Hours Ago</time>,
#  <time class="LatestNews-timestamp">16 Hours Ago</time>,
#  <time class="LatestNews-timestamp">16 Hours Ago</time>,
#  <time class="LatestNews-timestamp">17 Hours Ago</time>,
#  <time class="LatestNews-timestamp">17 Hours Ago</time>,
#  <time class="LatestNews-timestamp">17 Hours Ago</time>,
#  <time class="LatestNews-timestamp">December 16, 2022</time>,
# ...

# %%
ntimes = []
for play in scraped_times:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    ntimes.append(play)
print(ntimes)
# Out:
# ['6 Hours Ago', '7 Hours Ago', '13 Hours Ago', '13 Hours Ago', '15 Hours Ago', '15 Hours Ago', '15 Hours Ago', '15 Hours Ago', '16 Hours Ago', '16 Hours Ago', '16 Hours Ago', '16 Hours Ago', '17 Hours Ago', '17 Hours Ago', '17 Hours Ago', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022', 'December 16, 2022']

# %%
scraped_nlinks = soup.find_all('a',class_="LatestNews-headline")
scraped_nlinks
# Out:
# [<a class="LatestNews-headline" href="https://www.cnbc.com/2022/12/17/american-airlines-is-dropping-regional-carrier-mesa-citing-financial-and-operational-problems.html" title="American Airlines is dropping Mesa, citing financial and operational problems">American Airlines is dropping Mesa, citing financial and operational problems</a>,
#  <a class="LatestNews-headline" href="https://www.cnbc.com/2022/12/17/ftx-founder-sam-bankman-fried-will-not-contest-us-extradition-in-alleged-fraud-case-source-says.html" title="FTX founder Bankman-Fried will not contest U.S. extradition in alleged fraud case">FTX founder Bankman-Fried will not contest U.S. extradition in alleged fraud case</a>,
# ...

# %%
news_links=[]

# %%
for i in scraped_nlinks:
    news_links.append(i.get('href'))

# %%
news_links
# Out:
# ['https://www.cnbc.com/2022/12/17/american-airlines-is-dropping-regional-carrier-mesa-citing-financial-and-operational-problems.html',
#  'https://www.cnbc.com/2022/12/17/ftx-founder-sam-bankman-fried-will-not-contest-us-extradition-in-alleged-fraud-case-source-says.html',
#  'https://www.cnbc.com/2022/12/17/these-are-the-10-biggest-christmas-movies-everand-where-to-watch-them.html',
#  'https://www.cnbc.com/2022/12/17/here-are-10-cheap-or-totally-free-self-care-activities.html',
#  'https://www.cnbc.com/2022/12/17/rooftop-solar-how-homeowners-can-make-sense-of-the-climate-finance.html',
#  'https://www.cnbc.com/2022/12/17/4-red-flags-that-might-mean-your-relationship-is-in-trouble.html',
#  'https://www.cnbc.com/2022/12/17/why-annoying-captcha-is-still-big-for-google-e-commerce-in-bot-battle.html',
#  'https://www.cnbc.com/2022/12/17/ramit-sethi-this-is-the-biggest-barrier-to-starting-a-side-hustle.html',
# ...

# %%
len(news_links)
# Out:
# 30

# %%
df = pd.DataFrame({'Headline':nheadlines, 'Time':ntimes, 'News Link':news_links})
df
# Out:
#                                              Headline               Time  \
# 0   American Airlines is dropping Mesa, citing fin...        6 Hours Ago
# 1   FTX founder Bankman-Fried will not contest U.S...        7 Hours Ago
# 2   These are the 10 biggest Christmas movies ever...       13 Hours Ago
# 3   10 self-care activities that will cost you lit...       13 Hours Ago
# 4   Rooftop solar: How homeowners can make sense o...       15 Hours Ago
# 5   4 'red flags' that might mean your relationshi...       15 Hours Ago
# 6   Why annoying CAPTCHA is still big for Google a...       15 Hours Ago
# 7   The biggest barrier to starting a successful s...       15 Hours Ago
# 8   Airlines can price climate change into a plane...       16 Hours Ago
# 9   'It never feels like you're out of poverty': M...       16 Hours Ago
# 10  10 states where $1 million in retirement savin...       16 Hours Ago
# 11     How cloud seeding can boosst rain and snowfall       16 Hours Ago
# ...

# %% [markdown]
# ## Artificial Intelligence Srapping Data

# %%
web = requests.get("https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles")

# %%
web
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(web.content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="en_US" name="og:locale"/>
#   <meta content="Most Downloaded Articles - Artificial Intelligence - Journal - Elsevier" property="og:title"/>
#   <meta content="The journal of Artificial Intelligence (AIJ)  welcomes papers on broad aspects of AI that constitute advances in the overall field including, but not limited …" property="og:description"/>
#   <meta content="http://ars.els-cdn.com/content/image/X00043702.jpg" name="og:image" property="og:image"/>
#   <meta content="http://ars.els-cdn.com/content/image/X00043702.jpg" name="og:image:url" property="og:image:url"/>
#   <meta content="https://ars.els-cdn.com/content/image/X00043702.jpg" name="og:image:secure_url" property="og:image:secure_url"/>
#   <meta content="journals.elsevier.com/artificial-intelligence/most-downloaded-articles" name="og:url"/>
# ...

# %%
scraped_papertitle = soup.find_all('h2',class_="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg")
scraped_papertitle
# Out:
# [<h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Reward is enough</h2>,
#  <h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Making sense of raw input</h2>,
#  <h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Law and logic: A review from an argumentation perspective</h2>,
#  <h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Creativity and artificial intelligence</h2>,
#  <h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Artificial cognition for social human–robot interaction: An implementation</h2>,
#  <h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Explanation in artificial intelligence: Insights from the social sciences</h2>,
#  <h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Making sense of sensory input</h2>,
# ...

# %%
paper_titles = []
for play in scraped_papertitle:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    paper_titles.append(play)
print(paper_titles)
# Out:
# ['Reward is enough', 'Making sense of raw input', 'Law and logic: A review from an argumentation perspective', 'Creativity and artificial intelligence', 'Artificial cognition for social human–robot interaction: An implementation', 'Explanation in artificial intelligence: Insights from the social sciences', 'Making sense of sensory input', 'Conflict-based search for optimal multi-agent pathfinding', 'Between MDPs and semi-MDPs: A framework for temporal abstraction in reinforcement learning', 'The Hanabi challenge: A new frontier for AI research', 'Evaluating XAI: A comparison of rule-based and example-based explanations', 'Argumentation in artificial intelligence', 'Algorithms for computing strategies in two-player simultaneous move games', 'Multiple object tracking: A literature review', 'Selection of relevant features and examples in machine learning', 'A survey of inverse reinforcement learning: Challenges, methods and progress', 'Explaining individual predictions when features are
# ...

# %%
len(paper_titles)
# Out:
# 25

# %%
scraped_authors = soup.find_all('span',class_="sc-1w3fpd7-0 dnCnAO")
scraped_authors
# Out:
# [<span class="sc-1w3fpd7-0 dnCnAO">Silver, David, Singh, Satinder, Precup, Doina, Sutton, Richard S. </span>,
#  <span class="sc-1w3fpd7-0 dnCnAO">Evans, Richard, Bošnjak, Matko and 5 more</span>,
#  <span class="sc-1w3fpd7-0 dnCnAO">Prakken, Henry, Sartor, Giovanni </span>,
#  <span class="sc-1w3fpd7-0 dnCnAO">Boden, Margaret A. </span>,
#  <span class="sc-1w3fpd7-0 dnCnAO">Lemaignan, Séverin, Warnier, Mathieu and 3 more</span>,
#  <span class="sc-1w3fpd7-0 dnCnAO">Miller, Tim </span>,
#  <span class="sc-1w3fpd7-0 dnCnAO">Evans, Richard, Hernández-Orallo, José and 3 more</span>,
#  <span class="sc-1w3fpd7-0 dnCnAO">Sharon, Guni, Stern, Roni, Felner, Ariel, Sturtevant, Nathan R. </span>,
#  <span class="sc-1w3fpd7-0 dnCnAO">Sutton, Richard S., Precup, Doina, Singh, Satinder </span>,
#  <span class="sc-1w3fpd7-0 dnCnAO">Bard, Nolan, Foerster, Jakob N. and 13 more</span>,
# ...

# %%
AIauthors = []
for play in scraped_authors:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    AIauthors.append(play)
print(AIauthors)
# Out:
# ['Silver, David, Singh, Satinder, Precup, Doina, Sutton, Richard S.', 'Evans, Richard, Bošnjak, Matko and 5 more', 'Prakken, Henry, Sartor, Giovanni', 'Boden, Margaret A.', 'Lemaignan, Séverin, Warnier, Mathieu and 3 more', 'Miller, Tim', 'Evans, Richard, Hernández-Orallo, José and 3 more', 'Sharon, Guni, Stern, Roni, Felner, Ariel, Sturtevant, Nathan R.', 'Sutton, Richard S., Precup, Doina, Singh, Satinder', 'Bard, Nolan, Foerster, Jakob N. and 13 more', 'van der Waa, Jasper, Nieuwburg, Elisabeth, Cremers, Anita, Neerincx, Mark', 'Bench-Capon, T.J.M., Dunne, Paul E.', 'Bošanský, Branislav, Lisý, Viliam and 3 more', 'Luo, Wenhan, Xing, Junliang and 4 more', 'Blum, Avrim L., Langley, Pat', 'Arora, Saurabh, Doshi, Prashant', 'Aas, Kjersti, Jullum, Martin, Løland, Anders', 'Kliegr, Tomáš, Bahník, Štěpán, Fürnkranz, Johannes', 'Pereira, Gonçalo, Prada, Rui, Santos, Pedro A.', 'Riveiro, Maria, Thill, Serge', 'Kenny, Eoin M., Ford, Courtney, Quinn, Molly, Keane, Mark T.', 'Hutter, Frank, X
# ...

# %%
len(AIauthors)
# Out:
# 25

# %%
scraped_publisheddate = soup.find_all('span',class_="sc-1thf9ly-2 dvggWt")
scraped_publisheddate
# Out:
# [<span class="sc-1thf9ly-2 dvggWt"><span>October 2021</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>October 2021</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>October 2015</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>August 1998</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>June 2017</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>February 2019</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>April 2021</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>February 2015</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>August 1999</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>March 2020</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>February 2021</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>October 2007</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>August 2016</span></span>,
#  <span class="sc-1thf9ly-2 dvggWt"><span>April 2021</span></span>,
# ...

# %%
AIpublisheddate = []
for play in scraped_publisheddate:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    AIpublisheddate.append(play)
print(AIpublisheddate)
# Out:
# ['October 2021', 'October 2021', 'October 2015', 'August 1998', 'June 2017', 'February 2019', 'April 2021', 'February 2015', 'August 1999', 'March 2020', 'February 2021', 'October 2007', 'August 2016', 'April 2021', 'December 1997', 'August 2021', 'September 2021', 'June 2021', 'December 2016', 'September 2021', 'May 2021', 'January 2014', 'December 1997', 'October 2021', 'February 2010']

# %%
len(AIpublisheddate)
# Out:
# 25

# %%
scraped_paper_URL = soup.find_all('a',class_="sc-5smygv-0 fIXTHm")
scraped_paper_URL
# Out:
# [<a class="sc-5smygv-0 fIXTHm" href="https://www.sciencedirect.com/science/article/pii/S0004370221000862"><h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Reward is enough</h2></a>,
#  <a class="sc-5smygv-0 fIXTHm" href="https://www.sciencedirect.com/science/article/pii/S0004370221000722"><h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Making sense of raw input</h2></a>,
#  <a class="sc-5smygv-0 fIXTHm" href="https://www.sciencedirect.com/science/article/pii/S0004370215000910"><h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Law and logic: A review from an argumentation perspective</h2></a>,
#  <a class="sc-5smygv-0 fIXTHm" href="https://www.sciencedirect.com/science/article/pii/S0004370298000551"><h2 class="sc-1qrq3sd-1 gRGSUS sc-1nmom32-0 sc-1nmom32-1 btcbYu goSKRg">Creativity and artificial intelligence</h2></a>,
# ...

# %%
 AIpaper_URL= []
for i in scraped_paper_URL:
    AIpaper_URL.append(i.get('href'))
print(AIpaper_URL)
# Out:
# ['https://www.sciencedirect.com/science/article/pii/S0004370221000862', 'https://www.sciencedirect.com/science/article/pii/S0004370221000722', 'https://www.sciencedirect.com/science/article/pii/S0004370215000910', 'https://www.sciencedirect.com/science/article/pii/S0004370298000551', 'https://www.sciencedirect.com/science/article/pii/S0004370216300790', 'https://www.sciencedirect.com/science/article/pii/S0004370218305988', 'https://www.sciencedirect.com/science/article/pii/S0004370220301855', 'https://www.sciencedirect.com/science/article/pii/S0004370214001386', 'https://www.sciencedirect.com/science/article/pii/S0004370299000521', 'https://www.sciencedirect.com/science/article/pii/S0004370219300116', 'https://www.sciencedirect.com/science/article/pii/S0004370220301533', 'https://www.sciencedirect.com/science/article/pii/S0004370207000793', 'https://www.sciencedirect.com/science/article/pii/S0004370216300285', 'https://www.sciencedirect.com/science/article/pii/S0004370220301958', 'ht
# ...

# %%
len(AIpaper_URL)
# Out:
# 25

# %%
df = pd.DataFrame({'Paper title':paper_titles, 'Authors':AIauthors, 'Published Date':AIpublisheddate, 'Paper URL':AIpaper_URL})
df
# Out:
#                                           Paper title  \
# 0                                    Reward is enough
# 1                           Making sense of raw input
# 2   Law and logic: A review from an argumentation ...
# 3              Creativity and artificial intelligence
# 4   Artificial cognition for social human–robot in...
# 5   Explanation in artificial intelligence: Insigh...
# 6                       Making sense of sensory input
# 7   Conflict-based search for optimal multi-agent ...
# 8   Between MDPs and semi-MDPs: A framework for te...
# 9   The Hanabi challenge: A new frontier for AI re...
# 10  Evaluating XAI: A comparison of rule-based and...
# 11           Argumentation in artificial intelligence
# 12  Algorithms for computing strategies in two-pla...
# 13      Multiple object tracking: A literature review
# 14  Selection of relevant features and examples in...
# 15  A survey of inverse reinforcement learning: Ch...
# ...

# %% [markdown]
# ## Dineout

# %%
web = requests.get("https://www.dineout.co.in/delhi-restaurants/buffet-special")

# %%
web
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(web.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <style type="text/css">
#    @font-face {
#                 font-family: 'dineicon';
#                 src:  url('/fonts/dineicon.eot');
#                 src:  url('/fonts/dineicon.eot#iefix') format('embedded-opentype'),
#                 url('/fonts/dineicon.ttf') format('truetype'),
#                 url('/fonts/dineicon.woff') format('woff'),
#                 url('/fonts/dineicon.svg#dineicon') format('svg');
#                 font-weight: normal;
# 				font-style: normal;
# 				font-display: swap;
#             }
#             .hide {
#                 display: none !important;
#             }
#             .async-hide{
#                 opacity: inherit !important;
#             }
# ...

# %%
scraped_restaurantname = soup.find_all('a',class_="restnt-name ellipsis")
scraped_restaurantname
# Out:
# [<a analytics-action="RestaurantCardClick" analytics-label="86792_Castle Barbeque" class="restnt-name ellipsis" data-w-onclick="sendAnalyticsCommon|w1-restarant" href="/delhi/castle-barbeque-connaught-place-central-delhi-86792">Castle Barbeque</a>,
#  <a analytics-action="RestaurantCardClick" analytics-label="59633_Jungle Jamboree" class="restnt-name ellipsis" data-w-onclick="sendAnalyticsCommon|w1-restarant" href="/delhi/jungle-jamboree-lajpat-nagar-3-south-delhi-59633">Jungle Jamboree</a>,
#  <a analytics-action="RestaurantCardClick" analytics-label="406_Cafe Knosh" class="restnt-name ellipsis" data-w-onclick="sendAnalyticsCommon|w1-restarant" href="/delhi/cafe-knosh-shahdara-east-delhi-406">Cafe Knosh</a>,
#  <a analytics-action="RestaurantCardClick" analytics-label="38113_Castle Barbeque" class="restnt-name ellipsis" data-w-onclick="sendAnalyticsCommon|w1-restarant" href="/delhi/castle-barbeque-tagore-garden-west-delhi-38113">Castle Barbeque</a>,
# ...

# %%
drestaurantname = []
for play in scraped_restaurantname:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    drestaurantname.append(play)
print(drestaurantname)
# Out:
# ['Castle Barbeque', 'Jungle Jamboree', 'Cafe Knosh', 'Castle Barbeque', 'The Barbeque Company', 'India Grill', 'Delhi Barbeque', 'The Monarch - Bar Be Que Village', 'Indian Grill Room']

# %%
len(drestaurantname)
# Out:
# 9

# %%
scraped_cuisine = soup.find_all('span',class_="double-line-ellipsis")
scraped_cuisine
# Out:
# [<span class="double-line-ellipsis"><span>₹ 2,000 for 2 (approx)</span><span> | </span><a data-w-onclick="stopClickPropagation|w1-restarant" href="/delhi-restaurants/chinese-cuisine">Chinese</a><span>, </span><a data-w-onclick="stopClickPropagation|w1-restarant" href="/delhi-restaurants/north-indian-cuisine">North Indian</a></span>,
#  <span class="double-line-ellipsis"><span>₹ 1,680 for 2 (approx)</span><span> | </span><a data-w-onclick="stopClickPropagation|w1-restarant" href="/delhi-restaurants/north-indian-cuisine">North Indian</a><span>, </span><a data-w-onclick="stopClickPropagation|w1-restarant" href="/delhi-restaurants/asian-cuisine">Asian</a><span>, </span><a data-w-onclick="stopClickPropagation|w1-restarant" href="/delhi-restaurants/italian-cuisine">Italian</a></span>,
# ...

# %%
cuisines = []
prices = ['2,000','1,680','3,000','2,000','1,700','2,400','1,800','1,900','2,200']
for play in scraped_cuisine:
    play = play.get_text().replace(' for 2 (approx) | ', " ")
    play = play.replace('₹','')
    play = play.replace('2000','')
    play = play.strip(" ")
    cuisines.append(play)
cuisines
# Out:
# ['2,000 Chinese, North Indian',
#  '1,680 North Indian, Asian, Italian',
#  '3,000 Italian, Continental',
#  '2,000 Chinese, North Indian',
#  '1,700 North Indian, Chinese',
#  '2,400 North Indian, Italian',
#  '1,800 North Indian',
#  '1,900 North Indian',
#  '2,200 North Indian, Mughlai']

# %%
prices = ['2,000','1,680','3,000','2,000','1,700','2,400','1,800','1,900','2,200']
for i in prices:
    print(i)
# Out:
# 2,000
# 1,680
# 3,000
# 2,000
# 1,700
# 2,400
# 1,800
# 1,900
# 2,200

# %%
len(cuisines)
# Out:
# 9

# %%
scraped_location = soup.find_all('div',class_="restnt-loc ellipsis")
scraped_location
# Out:
# [<div class="restnt-loc ellipsis" data-w-onclick="stopClickPropagation|w1-restarant"><a data-name="Connaught Place" data-type="LocalityClick" href="/delhi-restaurants/central-delhi/connaught-place">Connaught Place</a>, <a data-name="Central Delhi" data-type="AreaClick" href="/delhi-restaurants/central-delhi">Central Delhi</a></div>,
#  <div class="restnt-loc ellipsis" data-w-onclick="stopClickPropagation|w1-restarant"><a href="/delhi-restaurants/3cs-mall-landmark">3CS Mall,</a><a data-name="Lajpat Nagar - 3" data-type="LocalityClick" href="/delhi-restaurants/south-delhi/lajpat-nagar-3">Lajpat Nagar - 3</a>, <a data-name="South Delhi" data-type="AreaClick" href="/delhi-restaurants/south-delhi">South Delhi</a></div>,
# ...

# %%
locations = []
for play in scraped_location:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    locations.append(play)
(locations)
# Out:
# ['Connaught Place, Central Delhi',
#  '3CS Mall,Lajpat Nagar - 3, South Delhi',
#  'The Leela Ambience Convention Hotel,Shahdara, East Delhi',
#  'Pacific Mall,Tagore Garden, West Delhi',
#  'Gardens Galleria,Sector 38A, Noida',
#  'Hilton Garden Inn,Saket, South Delhi',
#  'Taurus Sarovar Portico,Mahipalpur, South Delhi',
#  'Indirapuram Habitat Centre,Indirapuram, Ghaziabad',
#  'Suncity Business Tower,Golf Course Road, Gurgaon']

# %%
len(locations)
# Out:
# 9

# %%
scraped_rating = soup.find_all('div',class_="restnt-rating rating-4")
scraped_rating
# Out:
# [<div class="restnt-rating rating-4">4.1</div>,
#  <div class="restnt-rating rating-4">3.9</div>,
#  <div class="restnt-rating rating-4">4.3</div>,
#  <div class="restnt-rating rating-4">3.9</div>,
#  <div class="restnt-rating rating-4">4</div>,
#  <div class="restnt-rating rating-4">3.9</div>,
#  <div class="restnt-rating rating-4">3.6</div>,
#  <div class="restnt-rating rating-4">3.8</div>,
#  <div class="restnt-rating rating-4">4.3</div>]

# %%
ratings = []
for play in scraped_rating:
    play = play.get_text().replace('\n', "")
    play = play.strip(" ")
    ratings.append(play)
(ratings)
# Out:
# ['4.1', '3.9', '4.3', '3.9', '4', '3.9', '3.6', '3.8', '4.3']

# %%
len(ratings)
# Out:
# 9

# %%
scraped_imgURL = soup.find_all('img',class_="no-img")
scraped_imgURL
# Out:
# [<img alt="Castle Barbeque" class="lazy-load-img no-img" data-gatype="RestaurantImageClick" data-src="https://im1.dineout.co.in/images/uploads/restaurant/sharpen/8/k/b/p86792-16062953735fbe1f4d3fb7e.jpg?tr=tr:n-medium" data-url="/delhi/castle-barbeque-connaught-place-central-delhi-86792" data-w-onclick="cardClickHandler"/>,
#  <img alt="Jungle Jamboree" class="lazy-load-img no-img" data-gatype="RestaurantImageClick" data-src="https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/p/m/p59633-166088382462ff137009010.jpg?tr=tr:n-medium" data-url="/delhi/jungle-jamboree-lajpat-nagar-3-south-delhi-59633" data-w-onclick="cardClickHandler"/>,
#  <img alt="Cafe Knosh" class="lazy-load-img no-img" data-gatype="RestaurantImageClick" data-src="https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/p/m/p406-15438184745c04ccea491bc.jpg?tr=tr:n-medium" data-url="/delhi/cafe-knosh-shahdara-east-delhi-406" data-w-onclick="cardClickHandler"/>,
# ...

# %%
 Image_URL= []
for i in scraped_imgURL:
    Image_URL.append(i.get('data-src'))
print(Image_URL)
# Out:
# ['https://im1.dineout.co.in/images/uploads/restaurant/sharpen/8/k/b/p86792-16062953735fbe1f4d3fb7e.jpg?tr=tr:n-medium', 'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/p/m/p59633-166088382462ff137009010.jpg?tr=tr:n-medium', 'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/4/p/m/p406-15438184745c04ccea491bc.jpg?tr=tr:n-medium', 'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/j/o/p38113-15959192065f1fcb666130c.jpg?tr=tr:n-medium', 'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/7/p/k/p79307-16051787755fad1597f2bf9.jpg?tr=tr:n-medium', 'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/2/v/t/p2687-1482477169585cce712b90f.jpg?tr=tr:n-medium', 'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/5/d/i/p52501-1661855212630de5eceb6d2.jpg?tr=tr:n-medium', 'https://im1.dineout.co.in/images/uploads/restaurant/sharpen/3/n/o/p34822-15599107305cfa594a13c24.jpg?tr=tr:n-medium', 'https://im1.dineout.co.in/images/uploads/restau
# ...

# %%
len(Image_URL)
# Out:
# 9

# %%
df = pd.DataFrame({'Restaurant name':drestaurantname, 'Cuisine':cuisines, 'Location':locations, 'Ratings':ratings, 'Image URL':Image_URL})

# %%
df
# Out:
#                     Restaurant name                             Cuisine  \
# 0                   Castle Barbeque         2,000 Chinese, North Indian
# 1                   Jungle Jamboree  1,680 North Indian, Asian, Italian
# 2                        Cafe Knosh          3,000 Italian, Continental
# 3                   Castle Barbeque         2,000 Chinese, North Indian
# 4              The Barbeque Company         1,700 North Indian, Chinese
# 5                       India Grill         2,400 North Indian, Italian
# 6                    Delhi Barbeque                  1,800 North Indian
# 7  The Monarch - Bar Be Que Village                  1,900 North Indian
# 8                 Indian Grill Room         2,200 North Indian, Mughlai
#
#                                             Location Ratings  \
# 0                     Connaught Place, Central Delhi     4.1
# 1             3CS Mall,Lajpat Nagar - 3, South Delhi     3.9
# 2  The Leela Ambience Convention Hotel,Shahdara, ...     4.3
# ...

# %% [markdown]
# ## Top Publications From Google Scholar From

# %%
web2 = requests.get("https://scholar.google.com/citations?view_op=top_venues&hl")
import time
time.sleep(5)

# %%
web
# Out:
# <Response [429]>

# %%
soup = BeautifulSoup(web.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="initial-scale=1" name="viewport"/>
#   <title>
#    https://scholar.google.com/citations?view_op=top_venues&amp;hl=en
#   </title>
#  </head>
#  <body onload="e=document.getElementById('captcha');if(e){e.focus();} if(solveSimpleChallenge) {solveSimpleChallenge(,);}" style="font-family: arial, sans-serif; background-color: #fff; color: #000; padding:20px; font-size:18px;">
#   <div style="max-width:400px;">
#    <hr noshade="" size="1" style="color:#ccc; background-color:#ccc;"/>
#    <br/>
#    <div style="font-size:13px;">
#     Our systems have detected unusual traffic from your computer network.  Please try your request again later.
#     <a href="#" onclick="document.getElementById('infoDiv0').style.display='block';">
#      Why did this happen?
#     </a>
#     <br/>
#     <br/>
# ...

# %%
scraped_publication = soup.find_all('td',class_="gsc_mvt_t")
scraped_publication
# Out:
# []
